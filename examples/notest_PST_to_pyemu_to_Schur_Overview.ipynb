# %%
import pyemu
import os, shutil
import pandas as pd
import flopy
import numpy as np
import platform

# %% [markdown]
# # This notebook is designed to show high-level PST file generation and manipulation examples, and also highlight some of the steps that `Schur` object functions perform in a bit more detail
#
# The assumption is that a user has a model that `flopy` can grok. That's all we need, using the BOSS PEST-ification techniques `pyemu` has.

# %%
nam_file = "freyberg.nam"
org_model_ws = "Freyberg_transient"
new_model_ws = "pest_setup"
EXE_DIR = 'bin'
if os.path.exists(EXE_DIR):
    if "window" in platform.platform().lower():
        exe_files = [f for f in os.listdir(EXE_DIR) if f.endswith('exe')]
    else:
        exe_files = [f for f in os.listdir(EXE_DIR) if not f.endswith('exe')]
    [shutil.copy2(os.path.join(EXE_DIR,f),os.path.join('temp',f)) for f in exe_files]
# load the model, change dir and run once to get a hydmod output file and list file
m = flopy.modflow.Modflow.load(nam_file,model_ws=org_model_ws,check=False)
m.change_model_ws("temp",reset_external=True)
m.name = nam_file.split(".")[0]

# let's just retain the calibration data for now by trimming HYDMOD
hyd = m.get_package('hyd')
hyddf = pd.DataFrame(hyd.obsdata)
#hyddf = hyddf.loc[[True if 'cr' in i.decode() else False for i in hyddf.hydlbl]]
hyd.obsdata = hyddf.to_records(index=False).astype(hyd.obsdata.dtype)
hyd.nhyd = len(hyd.obsdata)
m.exe_name = 'mfnwt'
m.write_input()
pyemu.helpers.run('{0} {1}'.format(m.exe_name,nam_file), cwd='temp')
# Out:
# changing model workspace...
#    temp
# run():./mfnwt freyberg.nam

# %% [markdown]
# ## Let's make some parameters. How about zones for HK and a constants for SY and RCH?

# %%
zn_array = np.loadtxt(os.path.join("Freyberg_truth","hk.zones"))
k_zone_dict = {k:zn_array for k in range(m.nlay)}
const_props = []
const_props.append(["upw.sy", None])
const_props.append(["rch.rech",None])
zone_props = [['upw.hk',0]]

# %% [markdown]
# ## Maybe we ought to also treat well pumping as an uncertain parameter

# %%
bc_props = [["wel.flux",None]]

# %%
mfp = pyemu.helpers.PstFromFlopyModel(m,new_model_ws="schur_test",zone_props=zone_props,
                                          const_props=const_props,k_zone_dict=k_zone_dict,
                                          remove_existing=True,bc_props=bc_props)
# Out:
# 2017-12-03 11:38:05.416894 starting: updating model attributes
# 2017-12-03 11:38:05.417115 finished: updating model attributes took: 0:00:00.000221
# 2017-12-03 11:38:05.417202 WARNING: removing existing 'new_model_ws
#
# creating model workspace...
#    schur_test
#
# changing model workspace...
#    schur_test
# 2017-12-03 11:38:05.570162 starting: writing new modflow input files
# Util2d:delr: resetting 'how' to external
# Util2d:delc: resetting 'how' to external
# Util2d:model_top: resetting 'how' to external
# Util2d:botm_layer_0: resetting 'how' to external
# Util2d:botm_layer_1: resetting 'how' to external
# Util2d:botm_layer_2: resetting 'how' to external
# Util2d:ibound_layer_0: resetting 'how' to external
# Util2d:ibound_layer_1: resetting 'how' to external
# Util2d:ibound_layer_2: resetting 'how' to external
# Util2d:strt_layer_0: resetting 'how' to external
# Util2d:strt_layer_1: resetting 'how' to external
# Util2d:strt_layer_2: resetting 'how' to external
# Util2d:rech_1: resetting 'how' to external
# Util2d:rech_2: resetting 'how' to external
# Util2d:rech_3: resetting 'how' to external
# Util2d:rech_4: resetting 'how' to external
# Util2d:rech_5: resetting 'how' to external
# Util2d:rech_6: resetting 'how' to external
# Util2d:rech_7: resetting 'how' to external
# Util2d:rech_8: resetting 'how' to external
# Util2d:rech_9: resetting 'how' to external
# Util2d:rech_10: resetting 'how' to external
# Util2d:rech_11: resetting 'how' to external
# Util2d:rech_12: resetting 'how' to external
# Util2d:rech_13: resetting 'how' to external
# Util2d:rech_14: resetting 'how' to external
# Util2d:rech_15: resetting 'how' to external
# Util2d:rech_16: resetting 'how' to external
# Util2d:rech_17: resetting 'how' to external
# Util2d:rech_18: resetting 'how' to external
# Util2d:rech_19: resetting 'how' to external
# Util2d:rech_20: resetting 'how' to external
# Util2d:rech_21: resetting 'how' to external
# Util2d:rech_22: resetting 'how' to external
# Util2d:rech_23: resetting 'how' to external
# Util2d:rech_24: resetting 'how' to external
# Util2d:rech_25: resetting 'how' to external
# Util2d:rech_26: resetting 'how' to external
# Util2d:rech_27: resetting 'how' to external
# Util2d:rech_28: resetting 'how' to external
# Util2d:rech_29: resetting 'how' to external
# Util2d:rech_30: resetting 'how' to external
# Util2d:rech_31: resetting 'how' to external
# Util2d:rech_32: resetting 'how' to external
# Util2d:rech_33: resetting 'how' to external
# Util2d:rech_34: resetting 'how' to external
# Util2d:rech_35: resetting 'how' to external
# Util2d:rech_36: resetting 'how' to external
# Util2d:rech_37: resetting 'how' to external
# Util2d:rech_38: resetting 'how' to external
# Util2d:rech_39: resetting 'how' to external
# Util2d:rech_40: resetting 'how' to external
# Util2d:rech_41: resetting 'how' to external
# Util2d:rech_42: resetting 'how' to external
# Util2d:rech_43: resetting 'how' to external
# Util2d:rech_44: resetting 'how' to external
# Util2d:rech_45: resetting 'how' to external
# Util2d:rech_46: resetting 'how' to external
# Util2d:rech_47: resetting 'how' to external
# Util2d:rech_48: resetting 'how' to external
# Util2d:rech_49: resetting 'how' to external
# Util2d:rech_50: resetting 'how' to external
# Util2d:rech_51: resetting 'how' to external
# Util2d:rech_52: resetting 'how' to external
# Util2d:rech_53: resetting 'how' to external
# Util2d:rech_54: resetting 'how' to external
# Util2d:rech_55: resetting 'how' to external
# Util2d:rech_56: resetting 'how' to external
# Util2d:rech_57: resetting 'how' to external
# Util2d:rech_58: resetting 'how' to external
# Util2d:rech_59: resetting 'how' to external
# Util2d:rech_60: resetting 'how' to external
# Util2d:rech_61: resetting 'how' to external
# Util2d:rech_62: resetting 'how' to external
# Util2d:rech_63: resetting 'how' to external
# Util2d:rech_64: resetting 'how' to external
# Util2d:rech_65: resetting 'how' to external
# Util2d:rech_66: resetting 'how' to external
# Util2d:rech_67: resetting 'how' to external
# Util2d:rech_68: resetting 'how' to external
# Util2d:rech_69: resetting 'how' to external
# Util2d:rech_70: resetting 'how' to external
# Util2d:rech_71: resetting 'how' to external
# Util2d:rech_72: resetting 'how' to external
# Util2d:rech_73: resetting 'how' to external
# Util2d:rech_74: resetting 'how' to external
# Util2d:rech_75: resetting 'how' to external
# Util2d:rech_76: resetting 'how' to external
# Util2d:rech_77: resetting 'how' to external
# Util2d:rech_78: resetting 'how' to external
# Util2d:rech_79: resetting 'how' to external
# Util2d:rech_80: resetting 'how' to external
# Util2d:rech_81: resetting 'how' to external
# Util2d:rech_82: resetting 'how' to external
# Util2d:rech_83: resetting 'how' to external
# Util2d:rech_84: resetting 'how' to external
# Util2d:rech_85: resetting 'how' to external
# Util2d:rech_86: resetting 'how' to external
# Util2d:rech_87: resetting 'how' to external
# Util2d:rech_88: resetting 'how' to external
# Util2d:rech_89: resetting 'how' to external
# Util2d:rech_90: resetting 'how' to external
# Util2d:rech_91: resetting 'how' to external
# Util2d:rech_92: resetting 'how' to external
# Util2d:rech_93: resetting 'how' to external
# Util2d:rech_94: resetting 'how' to external
# Util2d:rech_95: resetting 'how' to external
# Util2d:rech_96: resetting 'how' to external
# Util2d:rech_97: resetting 'how' to external
# Util2d:rech_98: resetting 'how' to external
# Util2d:rech_99: resetting 'how' to external
# Util2d:rech_100: resetting 'how' to external
# Util2d:rech_101: resetting 'how' to external
# Util2d:rech_102: resetting 'how' to external
# Util2d:rech_103: resetting 'how' to external
# Util2d:rech_104: resetting 'how' to external
# Util2d:rech_105: resetting 'how' to external
# Util2d:rech_106: resetting 'how' to external
# Util2d:rech_107: resetting 'how' to external
# Util2d:rech_108: resetting 'how' to external
# Util2d:rech_109: resetting 'how' to external
# Util2d:rech_110: resetting 'how' to external
# Util2d:rech_111: resetting 'how' to external
# Util2d:rech_112: resetting 'how' to external
# Util2d:rech_113: resetting 'how' to external
# Util2d:rech_114: resetting 'how' to external
# Util2d:rech_115: resetting 'how' to external
# Util2d:rech_116: resetting 'how' to external
# Util2d:rech_117: resetting 'how' to external
# Util2d:rech_118: resetting 'how' to external
# Util2d:rech_119: resetting 'how' to external
# Util2d:rech_120: resetting 'how' to external
# Util2d:rech_121: resetting 'how' to external
# Util2d:rech_122: resetting 'how' to external
# Util2d:rech_123: resetting 'how' to external
# Util2d:rech_124: resetting 'how' to external
# Util2d:rech_125: resetting 'how' to external
# Util2d:rech_126: resetting 'how' to external
# Util2d:rech_127: resetting 'how' to external
# Util2d:rech_128: resetting 'how' to external
# Util2d:rech_129: resetting 'how' to external
# Util2d:rech_130: resetting 'how' to external
# Util2d:rech_131: resetting 'how' to external
# Util2d:rech_132: resetting 'how' to external
# Util2d:rech_133: resetting 'how' to external
# Util2d:rech_134: resetting 'how' to external
# Util2d:rech_135: resetting 'how' to external
# Util2d:rech_136: resetting 'how' to external
# Util2d:rech_137: resetting 'how' to external
# Util2d:rech_138: resetting 'how' to external
# Util2d:rech_139: resetting 'how' to external
# Util2d:rech_140: resetting 'how' to external
# Util2d:rech_141: resetting 'how' to external
# Util2d:rech_142: resetting 'how' to external
# Util2d:rech_143: resetting 'how' to external
# Util2d:rech_144: resetting 'how' to external
# Util2d:rech_145: resetting 'how' to external
# Util2d:rech_146: resetting 'how' to external
# Util2d:rech_147: resetting 'how' to external
# Util2d:rech_148: resetting 'how' to external
# Util2d:rech_149: resetting 'how' to external
# Util2d:rech_150: resetting 'how' to external
# Util2d:rech_151: resetting 'how' to external
# Util2d:rech_152: resetting 'how' to external
# Util2d:rech_153: resetting 'how' to external
# Util2d:rech_154: resetting 'how' to external
# Util2d:rech_155: resetting 'how' to external
# Util2d:rech_156: resetting 'how' to external
# Util2d:rech_157: resetting 'how' to external
# Util2d:rech_158: resetting 'how' to external
# Util2d:rech_159: resetting 'how' to external
# Util2d:rech_160: resetting 'how' to external
# Util2d:rech_161: resetting 'how' to external
# Util2d:rech_162: resetting 'how' to external
# Util2d:rech_163: resetting 'how' to external
# Util2d:rech_164: resetting 'how' to external
# Util2d:rech_165: resetting 'how' to external
# Util2d:rech_166: resetting 'how' to external
# Util2d:rech_167: resetting 'how' to external
# Util2d:rech_168: resetting 'how' to external
# Util2d:rech_169: resetting 'how' to external
# Util2d:rech_170: resetting 'how' to external
# Util2d:rech_171: resetting 'how' to external
# Util2d:rech_172: resetting 'how' to external
# Util2d:rech_173: resetting 'how' to external
# Util2d:rech_174: resetting 'how' to external
# Util2d:rech_175: resetting 'how' to external
# Util2d:rech_176: resetting 'how' to external
# Util2d:rech_177: resetting 'how' to external
# Util2d:rech_178: resetting 'how' to external
# Util2d:rech_179: resetting 'how' to external
# Util2d:rech_180: resetting 'how' to external
# Util2d:rech_181: resetting 'how' to external
# Util2d:rech_182: resetting 'how' to external
# Util2d:rech_183: resetting 'how' to external
# Util2d:rech_184: resetting 'how' to external
# Util2d:rech_185: resetting 'how' to external
# Util2d:rech_186: resetting 'how' to external
# Util2d:rech_187: resetting 'how' to external
# Util2d:rech_188: resetting 'how' to external
# Util2d:rech_189: resetting 'how' to external
# Util2d:rech_190: resetting 'how' to external
# Util2d:rech_191: resetting 'how' to external
# Util2d:rech_192: resetting 'how' to external
# Util2d:rech_193: resetting 'how' to external
# Util2d:rech_194: resetting 'how' to external
# Util2d:rech_195: resetting 'how' to external
# Util2d:rech_196: resetting 'how' to external
# Util2d:rech_197: resetting 'how' to external
# Util2d:rech_198: resetting 'how' to external
# Util2d:rech_199: resetting 'how' to external
# Util2d:rech_200: resetting 'how' to external
# Util2d:rech_201: resetting 'how' to external
# Util2d:rech_202: resetting 'how' to external
# Util2d:rech_203: resetting 'how' to external
# Util2d:rech_204: resetting 'how' to external
# Util2d:rech_205: resetting 'how' to external
# Util2d:rech_206: resetting 'how' to external
# Util2d:rech_207: resetting 'how' to external
# Util2d:rech_208: resetting 'how' to external
# Util2d:rech_209: resetting 'how' to external
# Util2d:rech_210: resetting 'how' to external
# Util2d:rech_211: resetting 'how' to external
# Util2d:rech_212: resetting 'how' to external
# Util2d:rech_213: resetting 'how' to external
# Util2d:rech_214: resetting 'how' to external
# Util2d:rech_215: resetting 'how' to external
# Util2d:rech_216: resetting 'how' to external
# Util2d:rech_217: resetting 'how' to external
# Util2d:rech_218: resetting 'how' to external
# Util2d:rech_219: resetting 'how' to external
# Util2d:rech_220: resetting 'how' to external
# Util2d:rech_221: resetting 'how' to external
# Util2d:rech_222: resetting 'how' to external
# Util2d:rech_223: resetting 'how' to external
# Util2d:rech_224: resetting 'how' to external
# Util2d:rech_225: resetting 'how' to external
# Util2d:rech_226: resetting 'how' to external
# Util2d:rech_227: resetting 'how' to external
# Util2d:rech_228: resetting 'how' to external
# Util2d:rech_229: resetting 'how' to external
# Util2d:rech_230: resetting 'how' to external
# Util2d:rech_231: resetting 'how' to external
# Util2d:rech_232: resetting 'how' to external
# Util2d:rech_233: resetting 'how' to external
# Util2d:rech_234: resetting 'how' to external
# Util2d:rech_235: resetting 'how' to external
# Util2d:rech_236: resetting 'how' to external
# Util2d:rech_237: resetting 'how' to external
# Util2d:rech_238: resetting 'how' to external
# Util2d:rech_239: resetting 'how' to external
# Util2d:rech_240: resetting 'how' to external
# Util2d:rech_241: resetting 'how' to external
# Util2d:rech_242: resetting 'how' to external
# Util2d:rech_243: resetting 'how' to external
# Util2d:rech_244: resetting 'how' to external
# Util2d:rech_245: resetting 'how' to external
# Util2d:rech_246: resetting 'how' to external
# Util2d:rech_247: resetting 'how' to external
# Util2d:rech_248: resetting 'how' to external
# Util2d:rech_249: resetting 'how' to external
# Util2d:rech_250: resetting 'how' to external
# Util2d:rech_251: resetting 'how' to external
# Util2d:rech_252: resetting 'how' to external
# Util2d:rech_253: resetting 'how' to external
# Util2d:rech_254: resetting 'how' to external
# Util2d:rech_255: resetting 'how' to external
# Util2d:rech_256: resetting 'how' to external
# Util2d:rech_257: resetting 'how' to external
# Util2d:rech_258: resetting 'how' to external
# Util2d:rech_259: resetting 'how' to external
# Util2d:rech_260: resetting 'how' to external
# Util2d:rech_261: resetting 'how' to external
# Util2d:rech_262: resetting 'how' to external
# Util2d:rech_263: resetting 'how' to external
# Util2d:rech_264: resetting 'how' to external
# Util2d:rech_265: resetting 'how' to external
# Util2d:rech_266: resetting 'how' to external
# Util2d:rech_267: resetting 'how' to external
# Util2d:rech_268: resetting 'how' to external
# Util2d:rech_269: resetting 'how' to external
# Util2d:rech_270: resetting 'how' to external
# Util2d:rech_271: resetting 'how' to external
# Util2d:rech_272: resetting 'how' to external
# Util2d:rech_273: resetting 'how' to external
# Util2d:rech_274: resetting 'how' to external
# Util2d:rech_275: resetting 'how' to external
# Util2d:rech_276: resetting 'how' to external
# Util2d:rech_277: resetting 'how' to external
# Util2d:rech_278: resetting 'how' to external
# Util2d:rech_279: resetting 'how' to external
# Util2d:rech_280: resetting 'how' to external
# Util2d:rech_281: resetting 'how' to external
# Util2d:rech_282: resetting 'how' to external
# Util2d:rech_283: resetting 'how' to external
# Util2d:rech_284: resetting 'how' to external
# Util2d:rech_285: resetting 'how' to external
# Util2d:rech_286: resetting 'how' to external
# Util2d:rech_287: resetting 'how' to external
# Util2d:rech_288: resetting 'how' to external
# Util2d:rech_289: resetting 'how' to external
# Util2d:rech_290: resetting 'how' to external
# Util2d:rech_291: resetting 'how' to external
# Util2d:rech_292: resetting 'how' to external
# Util2d:rech_293: resetting 'how' to external
# Util2d:rech_294: resetting 'how' to external
# Util2d:rech_295: resetting 'how' to external
# Util2d:rech_296: resetting 'how' to external
# Util2d:rech_297: resetting 'how' to external
# Util2d:rech_298: resetting 'how' to external
# Util2d:rech_299: resetting 'how' to external
# Util2d:rech_300: resetting 'how' to external
# Util2d:rech_301: resetting 'how' to external
# Util2d:rech_302: resetting 'how' to external
# Util2d:rech_303: resetting 'how' to external
# Util2d:rech_304: resetting 'how' to external
# Util2d:rech_305: resetting 'how' to external
# Util2d:rech_306: resetting 'how' to external
# Util2d:rech_307: resetting 'how' to external
# Util2d:rech_308: resetting 'how' to external
# Util2d:rech_309: resetting 'how' to external
# Util2d:rech_310: resetting 'how' to external
# Util2d:rech_311: resetting 'how' to external
# Util2d:rech_312: resetting 'how' to external
# Util2d:rech_313: resetting 'how' to external
# Util2d:rech_314: resetting 'how' to external
# Util2d:rech_315: resetting 'how' to external
# Util2d:rech_316: resetting 'how' to external
# Util2d:rech_317: resetting 'how' to external
# Util2d:rech_318: resetting 'how' to external
# Util2d:rech_319: resetting 'how' to external
# Util2d:rech_320: resetting 'how' to external
# Util2d:rech_321: resetting 'how' to external
# Util2d:rech_322: resetting 'how' to external
# Util2d:rech_323: resetting 'how' to external
# Util2d:rech_324: resetting 'how' to external
# Util2d:rech_325: resetting 'how' to external
# Util2d:rech_326: resetting 'how' to external
# Util2d:rech_327: resetting 'how' to external
# Util2d:rech_328: resetting 'how' to external
# Util2d:rech_329: resetting 'how' to external
# Util2d:rech_330: resetting 'how' to external
# Util2d:rech_331: resetting 'how' to external
# Util2d:rech_332: resetting 'how' to external
# Util2d:rech_333: resetting 'how' to external
# Util2d:rech_334: resetting 'how' to external
# Util2d:rech_335: resetting 'how' to external
# Util2d:rech_336: resetting 'how' to external
# Util2d:rech_337: resetting 'how' to external
# Util2d:rech_338: resetting 'how' to external
# Util2d:rech_339: resetting 'how' to external
# Util2d:rech_340: resetting 'how' to external
# Util2d:rech_341: resetting 'how' to external
# Util2d:rech_342: resetting 'how' to external
# Util2d:rech_343: resetting 'how' to external
# Util2d:rech_344: resetting 'how' to external
# Util2d:rech_345: resetting 'how' to external
# Util2d:rech_346: resetting 'how' to external
# Util2d:rech_347: resetting 'how' to external
# Util2d:rech_348: resetting 'how' to external
# Util2d:rech_349: resetting 'how' to external
# Util2d:rech_350: resetting 'how' to external
# Util2d:rech_351: resetting 'how' to external
# Util2d:rech_352: resetting 'how' to external
# Util2d:rech_353: resetting 'how' to external
# Util2d:rech_354: resetting 'how' to external
# Util2d:rech_355: resetting 'how' to external
# Util2d:rech_356: resetting 'how' to external
# Util2d:rech_357: resetting 'how' to external
# Util2d:rech_358: resetting 'how' to external
# Util2d:rech_359: resetting 'how' to external
# Util2d:rech_360: resetting 'how' to external
# Util2d:rech_361: resetting 'how' to external
# Util2d:rech_362: resetting 'how' to external
# Util2d:rech_363: resetting 'how' to external
# Util2d:rech_364: resetting 'how' to external
# Util2d:rech_365: resetting 'how' to external
# Util2d:hk: resetting 'how' to external
# Util2d:vka: resetting 'how' to external
# Util2d:ss: resetting 'how' to external
# Util2d:sy: resetting 'how' to external
# Util2d:hk: resetting 'how' to external
# Util2d:vka: resetting 'how' to external
# Util2d:ss: resetting 'how' to external
# Util2d:sy: resetting 'how' to external
# Util2d:hk: resetting 'how' to external
# Util2d:vka: resetting 'how' to external
# Util2d:ss: resetting 'how' to external
# Util2d:sy: resetting 'how' to external
# 2017-12-03 11:38:06.399023 finished: writing new modflow input files took: 0:00:00.828861
# 2017-12-03 11:38:06.399616 WARNING: using flopy binary to execute the model:MODFLOW 3 layer(s), 40 row(s), 20 column(s), 365 stress period(s)
# 2017-12-03 11:38:06.399771 forward_run line:pyemu.helpers.run('mfnwt freyberg.nam 1>freyberg.nam.stdout 2>freyberg.nam.stderr')
# 2017-12-03 11:38:06.400103 starting: setting up 'schur_test/arr_org' dir
# 2017-12-03 11:38:06.400441 finished: setting up 'schur_test/arr_org' dir took: 0:00:00.000338
# 2017-12-03 11:38:06.400520 starting: setting up 'schur_test/arr_mlt' dir
# 2017-12-03 11:38:06.400656 finished: setting up 'schur_test/arr_mlt' dir took: 0:00:00.000136
# 2017-12-03 11:38:06.400729 starting: setting up 'schur_test/bc_org' dir
# 2017-12-03 11:38:06.401139 finished: setting up 'schur_test/bc_org' dir took: 0:00:00.000410
# 2017-12-03 11:38:06.401244 starting: processing bc_props
# 2017-12-03 11:38:06.520101 starting: processing bc_prop_dict
# 2017-12-03 11:38:08.040297 forward_run line:pyemu.helpers.apply_bc_pars()
#
# 2017-12-03 11:38:08.405044 starting: writing zone tpl:hk0.dat_zn.tpl
# 2017-12-03 11:38:08.410700 finished: writing zone tpl:hk0.dat_zn.tpl took: 0:00:00.005656
# 2017-12-03 11:38:08.413184 starting: writing const tpl:sy0.dat_cn.tpl
# 2017-12-03 11:38:08.417601 finished: writing const tpl:sy0.dat_cn.tpl took: 0:00:00.004417
# 2017-12-03 11:38:08.419466 starting: writing const tpl:rech0.dat_cn.tpl
# 2017-12-03 11:38:08.424651 finished: writing const tpl:rech0.dat_cn.tpl took: 0:00:00.005185
# 2017-12-03 11:38:08.430474 starting: save test mlt array arr_mlt/hk0.dat_zn
# 2017-12-03 11:38:08.431782 finished: save test mlt array arr_mlt/hk0.dat_zn took: 0:00:00.001308
# 2017-12-03 11:38:08.432020 starting: save test mlt array arr_mlt/sy0.dat_cn
# 2017-12-03 11:38:08.433280 finished: save test mlt array arr_mlt/sy0.dat_cn took: 0:00:00.001260
# 2017-12-03 11:38:08.433375 starting: save test mlt array arr_mlt/rech0.dat_cn
# 2017-12-03 11:38:08.434254 finished: save test mlt array arr_mlt/rech0.dat_cn took: 0:00:00.000879
# 2017-12-03 11:38:09.574071 forward_run line:pyemu.helpers.apply_array_pars()
#
# 2017-12-03 11:38:09.574292 starting: processing obs type mflist water budget obs
# run():inschek schur_test/flux.dat.ins schur_test/flux.dat
# run():inschek schur_test/vol.dat.ins schur_test/vol.dat
# run():inschek schur_test/flux.dat.ins schur_test/flux.dat
# run():inschek schur_test/vol.dat.ins schur_test/vol.dat
# 2017-12-03 11:38:10.310681 forward_run line:pyemu.gw_utils.apply_mflist_budget_obs('freyberg.list',flx_filename='flux.dat',vol_filename='vol.dat',start_datetime='1/1/2015')
# 2017-12-03 11:38:10.310998 finished: processing obs type mflist water budget obs took: 0:00:00.736706
# 2017-12-03 11:38:10.311118 starting: processing obs type hyd file
# Starting to read HYDMOD data from schur_test/freyberg.hyd.bin
# 2017-12-03 11:38:50.827892 forward_run line: pyemu.gw_utils.modflow_read_hydmod_file('freyberg.hyd.bin')
# 2017-12-03 11:38:50.828976 finished: processing obs type hyd file took: 0:00:40.517858
# 2017-12-03 11:38:50.829307 starting: processing obs type external obs-sim smp files
# 2017-12-03 11:38:50.829497 finished: processing obs type external obs-sim smp files took: 0:00:00.000190
# 2017-12-03 11:38:50.829730 starting: processing obs type hob
# 2017-12-03 11:38:50.829813 finished: processing obs type hob took: 0:00:00.000083
# 2017-12-03 11:38:50.829849 starting: processing obs type hds
# 2017-12-03 11:38:50.829897 finished: processing obs type hds took: 0:00:00.000048
# 2017-12-03 11:38:50.829939 starting: changing dir in to schur_test
# run():inschek flux.dat.ins flux.dat
# run():inschek freyberg.hyd.bin.dat.ins freyberg.hyd.bin.dat
# error using inschek for instruction file freyberg.hyd.bin.dat.ins:File b'freyberg.hyd.bin.dat.obf' does not exist
# observations in this instruction file will havegeneric values.
# run():inschek vol.dat.ins vol.dat
# 2017-12-03 11:39:02.067285 starting: writing forward_run.py
# 2017-12-03 11:39:02.068019 finished: writing forward_run.py took: 0:00:00.000734
# 2017-12-03 11:39:02.068205 writing pst schur_test/freyberg_pest.pst
# 2017-12-03 11:39:12.370730 starting: running pestchek on freyberg_pest.pst
# run():pestchek freyberg_pest.pst >pestchek.stdout
# 2017-12-03 11:39:14.466981 pestcheck:PESTCHEK Version 13.0. Watermark Numerical Computing.
# 2017-12-03 11:39:14.467114 pestcheck:
# 2017-12-03 11:39:14.467173 pestcheck:Errors ----->
# 2017-12-03 11:39:14.467752 pestcheck:Line 240772 of file freyberg_pest.pst: model input file arr_mlt/sy0.dat_cn
# 2017-12-03 11:39:14.467860 pestcheck:cited more than once.
# 2017-12-03 11:39:14.468117 pestcheck:Line 240773 of file freyberg_pest.pst: model input file arr_mlt/sy0.dat_cn
# 2017-12-03 11:39:14.468173 pestcheck:cited more than once.
# 2017-12-03 11:39:14.468276 pestcheck:Line 240775 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.468326 pestcheck:cited more than once.
# 2017-12-03 11:39:14.468357 pestcheck:Line 240776 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.468383 pestcheck:cited more than once.
# 2017-12-03 11:39:14.468408 pestcheck:Line 240777 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.468432 pestcheck:cited more than once.
# 2017-12-03 11:39:14.468579 pestcheck:Line 240778 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.468628 pestcheck:cited more than once.
# 2017-12-03 11:39:14.468720 pestcheck:Line 240779 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.468749 pestcheck:cited more than once.
# 2017-12-03 11:39:14.468835 pestcheck:Line 240780 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.468866 pestcheck:cited more than once.
# 2017-12-03 11:39:14.468941 pestcheck:Line 240781 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.468971 pestcheck:cited more than once.
# 2017-12-03 11:39:14.468994 pestcheck:Line 240782 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.469123 pestcheck:cited more than once.
# 2017-12-03 11:39:14.469151 pestcheck:Line 240783 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.469222 pestcheck:cited more than once.
# 2017-12-03 11:39:14.469249 pestcheck:Line 240784 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.469304 pestcheck:cited more than once.
# 2017-12-03 11:39:14.469330 pestcheck:Line 240785 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.469392 pestcheck:cited more than once.
# 2017-12-03 11:39:14.469418 pestcheck:Line 240786 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.469530 pestcheck:cited more than once.
# 2017-12-03 11:39:14.469695 pestcheck:Line 240787 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.469804 pestcheck:cited more than once.
# 2017-12-03 11:39:14.469911 pestcheck:Line 240788 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.469992 pestcheck:cited more than once.
# 2017-12-03 11:39:14.470096 pestcheck:Line 240789 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.470178 pestcheck:cited more than once.
# 2017-12-03 11:39:14.470283 pestcheck:Line 240790 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.470390 pestcheck:cited more than once.
# 2017-12-03 11:39:14.470469 pestcheck:Line 240791 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.470574 pestcheck:cited more than once.
# 2017-12-03 11:39:14.470671 pestcheck:Line 240792 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.470789 pestcheck:cited more than once.
# 2017-12-03 11:39:14.470896 pestcheck:Line 240793 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.470976 pestcheck:cited more than once.
# 2017-12-03 11:39:14.471083 pestcheck:Line 240794 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.471178 pestcheck:cited more than once.
# 2017-12-03 11:39:14.471294 pestcheck:Line 240795 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.471423 pestcheck:cited more than once.
# 2017-12-03 11:39:14.471506 pestcheck:Line 240796 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.471610 pestcheck:cited more than once.
# 2017-12-03 11:39:14.471716 pestcheck:Line 240797 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.471823 pestcheck:cited more than once.
# 2017-12-03 11:39:14.471951 pestcheck:Line 240798 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.472032 pestcheck:cited more than once.
# 2017-12-03 11:39:14.472137 pestcheck:Line 240799 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.472239 pestcheck:cited more than once.
# 2017-12-03 11:39:14.472368 pestcheck:Line 240800 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.472452 pestcheck:cited more than once.
# 2017-12-03 11:39:14.472554 pestcheck:Line 240801 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.472666 pestcheck:cited more than once.
# 2017-12-03 11:39:14.472760 pestcheck:Line 240802 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.472872 pestcheck:cited more than once.
# 2017-12-03 11:39:14.472981 pestcheck:Line 240803 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.473063 pestcheck:cited more than once.
# 2017-12-03 11:39:14.473172 pestcheck:Line 240804 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.473265 pestcheck:cited more than once.
# 2017-12-03 11:39:14.473380 pestcheck:Line 240805 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.473486 pestcheck:cited more than once.
# 2017-12-03 11:39:14.473565 pestcheck:Line 240806 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.473669 pestcheck:cited more than once.
# 2017-12-03 11:39:14.473775 pestcheck:Line 240807 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.473880 pestcheck:cited more than once.
# 2017-12-03 11:39:14.473982 pestcheck:Line 240808 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.474089 pestcheck:cited more than once.
# 2017-12-03 11:39:14.474191 pestcheck:Line 240809 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.474294 pestcheck:cited more than once.
# 2017-12-03 11:39:14.474397 pestcheck:Line 240810 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.474472 pestcheck:cited more than once.
# 2017-12-03 11:39:14.474570 pestcheck:Line 240811 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.474679 pestcheck:cited more than once.
# 2017-12-03 11:39:14.474736 pestcheck:Line 240812 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.474842 pestcheck:cited more than once.
# 2017-12-03 11:39:14.474902 pestcheck:Line 240813 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.474985 pestcheck:cited more than once.
# 2017-12-03 11:39:14.475180 pestcheck:Line 240814 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.475233 pestcheck:cited more than once.
# 2017-12-03 11:39:14.475355 pestcheck:Line 240815 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.475459 pestcheck:cited more than once.
# 2017-12-03 11:39:14.475546 pestcheck:Line 240816 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.475667 pestcheck:cited more than once.
# 2017-12-03 11:39:14.475768 pestcheck:Line 240817 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.475870 pestcheck:cited more than once.
# 2017-12-03 11:39:14.475932 pestcheck:Line 240818 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.476010 pestcheck:cited more than once.
# 2017-12-03 11:39:14.476113 pestcheck:Line 240819 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.476168 pestcheck:cited more than once.
# 2017-12-03 11:39:14.476270 pestcheck:Line 240820 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.476327 pestcheck:cited more than once.
# 2017-12-03 11:39:14.476407 pestcheck:Line 240821 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.476509 pestcheck:cited more than once.
# 2017-12-03 11:39:14.476547 pestcheck:Line 240822 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.476644 pestcheck:cited more than once.
# 2017-12-03 11:39:14.476746 pestcheck:Line 240823 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.476801 pestcheck:cited more than once.
# 2017-12-03 11:39:14.476903 pestcheck:Line 240824 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.476957 pestcheck:cited more than once.
# 2017-12-03 11:39:14.477059 pestcheck:Line 240825 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.477115 pestcheck:cited more than once.
# 2017-12-03 11:39:14.477191 pestcheck:Line 240826 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.477292 pestcheck:cited more than once.
# 2017-12-03 11:39:14.477343 pestcheck:Line 240827 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.477444 pestcheck:cited more than once.
# 2017-12-03 11:39:14.477502 pestcheck:Line 240828 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.477579 pestcheck:cited more than once.
# 2017-12-03 11:39:14.477716 pestcheck:Line 240829 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.477768 pestcheck:cited more than once.
# 2017-12-03 11:39:14.477871 pestcheck:Line 240830 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.477927 pestcheck:cited more than once.
# 2017-12-03 11:39:14.478037 pestcheck:Line 240831 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.478150 pestcheck:cited more than once.
# 2017-12-03 11:39:14.478206 pestcheck:Line 240832 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.478310 pestcheck:cited more than once.
# 2017-12-03 11:39:14.478370 pestcheck:Line 240833 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.478449 pestcheck:cited more than once.
# 2017-12-03 11:39:14.478550 pestcheck:Line 240834 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.478601 pestcheck:cited more than once.
# 2017-12-03 11:39:14.478740 pestcheck:Line 240835 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.478846 pestcheck:cited more than once.
# 2017-12-03 11:39:14.478903 pestcheck:Line 240836 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.479005 pestcheck:cited more than once.
# 2017-12-03 11:39:14.479056 pestcheck:Line 240837 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.479159 pestcheck:cited more than once.
# 2017-12-03 11:39:14.479236 pestcheck:Line 240838 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.479292 pestcheck:cited more than once.
# 2017-12-03 11:39:14.479394 pestcheck:Line 240839 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.479445 pestcheck:cited more than once.
# 2017-12-03 11:39:14.479549 pestcheck:Line 240840 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.479607 pestcheck:cited more than once.
# 2017-12-03 11:39:14.479683 pestcheck:Line 240841 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.479784 pestcheck:cited more than once.
# 2017-12-03 11:39:14.479835 pestcheck:Line 240842 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.479937 pestcheck:cited more than once.
# 2017-12-03 11:39:14.479992 pestcheck:Line 240843 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.480093 pestcheck:cited more than once.
# 2017-12-03 11:39:14.480169 pestcheck:Line 240844 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.480243 pestcheck:cited more than once.
# 2017-12-03 11:39:14.480359 pestcheck:Line 240845 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.480395 pestcheck:cited more than once.
# 2017-12-03 11:39:14.480477 pestcheck:Line 240846 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.480582 pestcheck:cited more than once.
# 2017-12-03 11:39:14.480679 pestcheck:Line 240847 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.480792 pestcheck:cited more than once.
# 2017-12-03 11:39:14.480852 pestcheck:Line 240848 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.480952 pestcheck:cited more than once.
# 2017-12-03 11:39:14.481011 pestcheck:Line 240849 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.481104 pestcheck:cited more than once.
# 2017-12-03 11:39:14.481217 pestcheck:Line 240850 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.481277 pestcheck:cited more than once.
# 2017-12-03 11:39:14.481409 pestcheck:Line 240851 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.481502 pestcheck:cited more than once.
# 2017-12-03 11:39:14.481560 pestcheck:Line 240852 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.481664 pestcheck:cited more than once.
# 2017-12-03 11:39:14.481721 pestcheck:Line 240853 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.481820 pestcheck:cited more than once.
# 2017-12-03 11:39:14.481878 pestcheck:Line 240854 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.481977 pestcheck:cited more than once.
# 2017-12-03 11:39:14.482033 pestcheck:Line 240855 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.482134 pestcheck:cited more than once.
# 2017-12-03 11:39:14.482206 pestcheck:Line 240856 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.482318 pestcheck:cited more than once.
# 2017-12-03 11:39:14.482403 pestcheck:Line 240857 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.482488 pestcheck:cited more than once.
# 2017-12-03 11:39:14.482596 pestcheck:Line 240858 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.482654 pestcheck:cited more than once.
# 2017-12-03 11:39:14.482740 pestcheck:Line 240859 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.482844 pestcheck:cited more than once.
# 2017-12-03 11:39:14.482900 pestcheck:Line 240860 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.483001 pestcheck:cited more than once.
# 2017-12-03 11:39:14.483055 pestcheck:Line 240861 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.483155 pestcheck:cited more than once.
# 2017-12-03 11:39:14.483205 pestcheck:Line 240862 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.483307 pestcheck:cited more than once.
# 2017-12-03 11:39:14.483364 pestcheck:Line 240863 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.483441 pestcheck:cited more than once.
# 2017-12-03 11:39:14.483539 pestcheck:Line 240864 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.483592 pestcheck:cited more than once.
# 2017-12-03 11:39:14.483693 pestcheck:Line 240865 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.483751 pestcheck:cited more than once.
# 2017-12-03 11:39:14.483826 pestcheck:Line 240866 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.483908 pestcheck:cited more than once.
# 2017-12-03 11:39:14.484009 pestcheck:Line 240867 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.484065 pestcheck:cited more than once.
# 2017-12-03 11:39:14.484165 pestcheck:Line 240868 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.484220 pestcheck:cited more than once.
# 2017-12-03 11:39:14.484320 pestcheck:Line 240869 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.484370 pestcheck:cited more than once.
# 2017-12-03 11:39:14.484455 pestcheck:Line 240870 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.484556 pestcheck:cited more than once.
# 2017-12-03 11:39:14.484610 pestcheck:Line 240871 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.484711 pestcheck:cited more than once.
# 2017-12-03 11:39:14.484750 pestcheck:Line 240872 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.484846 pestcheck:cited more than once.
# 2017-12-03 11:39:14.484945 pestcheck:Line 240873 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.485000 pestcheck:cited more than once.
# 2017-12-03 11:39:14.485100 pestcheck:Line 240874 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.485170 pestcheck:cited more than once.
# 2017-12-03 11:39:14.485288 pestcheck:Line 240875 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.485350 pestcheck:cited more than once.
# 2017-12-03 11:39:14.485432 pestcheck:Line 240876 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.485535 pestcheck:cited more than once.
# 2017-12-03 11:39:14.485587 pestcheck:Line 240877 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.485690 pestcheck:cited more than once.
# 2017-12-03 11:39:14.485746 pestcheck:Line 240878 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.485825 pestcheck:cited more than once.
# 2017-12-03 11:39:14.485924 pestcheck:Line 240879 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.486021 pestcheck:cited more than once.
# 2017-12-03 11:39:14.486131 pestcheck:Line 240880 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.486219 pestcheck:cited more than once.
# 2017-12-03 11:39:14.486274 pestcheck:Line 240881 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.486391 pestcheck:cited more than once.
# 2017-12-03 11:39:14.486455 pestcheck:Line 240882 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.486562 pestcheck:cited more than once.
# 2017-12-03 11:39:14.486620 pestcheck:Line 240883 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.486698 pestcheck:cited more than once.
# 2017-12-03 11:39:14.486800 pestcheck:Line 240884 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.486867 pestcheck:cited more than once.
# 2017-12-03 11:39:14.486957 pestcheck:Line 240885 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.487066 pestcheck:cited more than once.
# 2017-12-03 11:39:14.487126 pestcheck:Line 240886 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.487222 pestcheck:cited more than once.
# 2017-12-03 11:39:14.487318 pestcheck:Line 240887 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.487405 pestcheck:cited more than once.
# 2017-12-03 11:39:14.487512 pestcheck:Line 240888 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.487574 pestcheck:cited more than once.
# 2017-12-03 11:39:14.487655 pestcheck:Line 240889 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.487755 pestcheck:cited more than once.
# 2017-12-03 11:39:14.487812 pestcheck:Line 240890 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.487915 pestcheck:cited more than once.
# 2017-12-03 11:39:14.487991 pestcheck:Line 240891 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.488047 pestcheck:cited more than once.
# 2017-12-03 11:39:14.488142 pestcheck:Line 240892 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.488245 pestcheck:cited more than once.
# 2017-12-03 11:39:14.488355 pestcheck:Line 240893 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.488411 pestcheck:cited more than once.
# 2017-12-03 11:39:14.488513 pestcheck:Line 240894 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.488565 pestcheck:cited more than once.
# 2017-12-03 11:39:14.488643 pestcheck:Line 240895 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.488745 pestcheck:cited more than once.
# 2017-12-03 11:39:14.488799 pestcheck:Line 240896 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.488884 pestcheck:cited more than once.
# 2017-12-03 11:39:14.488947 pestcheck:Line 240897 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.489060 pestcheck:cited more than once.
# 2017-12-03 11:39:14.489162 pestcheck:Line 240898 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.489217 pestcheck:cited more than once.
# 2017-12-03 11:39:14.489319 pestcheck:Line 240899 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.489371 pestcheck:cited more than once.
# 2017-12-03 11:39:14.489455 pestcheck:Line 240900 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.489542 pestcheck:cited more than once.
# 2017-12-03 11:39:14.489620 pestcheck:Line 240901 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.489712 pestcheck:cited more than once.
# 2017-12-03 11:39:14.489808 pestcheck:Line 240902 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.489916 pestcheck:cited more than once.
# 2017-12-03 11:39:14.489975 pestcheck:Line 240903 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.490054 pestcheck:cited more than once.
# 2017-12-03 11:39:14.490156 pestcheck:Line 240904 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.490211 pestcheck:cited more than once.
# 2017-12-03 11:39:14.490314 pestcheck:Line 240905 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.490371 pestcheck:cited more than once.
# 2017-12-03 11:39:14.490448 pestcheck:Line 240906 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.490549 pestcheck:cited more than once.
# 2017-12-03 11:39:14.490600 pestcheck:Line 240907 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.490701 pestcheck:cited more than once.
# 2017-12-03 11:39:14.490813 pestcheck:Line 240908 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.490871 pestcheck:cited more than once.
# 2017-12-03 11:39:14.490952 pestcheck:Line 240909 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.491049 pestcheck:cited more than once.
# 2017-12-03 11:39:14.491104 pestcheck:Line 240910 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.491207 pestcheck:cited more than once.
# 2017-12-03 11:39:14.491262 pestcheck:Line 240911 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.491360 pestcheck:cited more than once.
# 2017-12-03 11:39:14.491452 pestcheck:Line 240912 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.491539 pestcheck:cited more than once.
# 2017-12-03 11:39:14.491644 pestcheck:Line 240913 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.491700 pestcheck:cited more than once.
# 2017-12-03 11:39:14.491802 pestcheck:Line 240914 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.491857 pestcheck:cited more than once.
# 2017-12-03 11:39:14.491958 pestcheck:Line 240915 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.492015 pestcheck:cited more than once.
# 2017-12-03 11:39:14.492092 pestcheck:Line 240916 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.492193 pestcheck:cited more than once.
# 2017-12-03 11:39:14.492249 pestcheck:Line 240917 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.492350 pestcheck:cited more than once.
# 2017-12-03 11:39:14.492468 pestcheck:Line 240918 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.492639 pestcheck:cited more than once.
# 2017-12-03 11:39:14.492766 pestcheck:Line 240919 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.492822 pestcheck:cited more than once.
# 2017-12-03 11:39:14.492928 pestcheck:Line 240920 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.492989 pestcheck:cited more than once.
# 2017-12-03 11:39:14.493068 pestcheck:Line 240921 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.493170 pestcheck:cited more than once.
# 2017-12-03 11:39:14.493207 pestcheck:Line 240922 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.493303 pestcheck:cited more than once.
# 2017-12-03 11:39:14.493391 pestcheck:Line 240923 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.493470 pestcheck:cited more than once.
# 2017-12-03 11:39:14.493571 pestcheck:Line 240924 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.493622 pestcheck:cited more than once.
# 2017-12-03 11:39:14.493720 pestcheck:Line 240925 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.493850 pestcheck:cited more than once.
# 2017-12-03 11:39:14.493913 pestcheck:Line 240926 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.494018 pestcheck:cited more than once.
# 2017-12-03 11:39:14.494070 pestcheck:Line 240927 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.494175 pestcheck:cited more than once.
# 2017-12-03 11:39:14.494231 pestcheck:Line 240928 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.494334 pestcheck:cited more than once.
# 2017-12-03 11:39:14.494390 pestcheck:Line 240929 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.494506 pestcheck:cited more than once.
# 2017-12-03 11:39:14.494564 pestcheck:Line 240930 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.494666 pestcheck:cited more than once.
# 2017-12-03 11:39:14.494721 pestcheck:Line 240931 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.494800 pestcheck:cited more than once.
# 2017-12-03 11:39:14.494894 pestcheck:Line 240932 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.495009 pestcheck:cited more than once.
# 2017-12-03 11:39:14.495069 pestcheck:Line 240933 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.495153 pestcheck:cited more than once.
# 2017-12-03 11:39:14.495254 pestcheck:Line 240934 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.495321 pestcheck:cited more than once.
# 2017-12-03 11:39:14.495434 pestcheck:Line 240935 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.495493 pestcheck:cited more than once.
# 2017-12-03 11:39:14.495575 pestcheck:Line 240936 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.495678 pestcheck:cited more than once.
# 2017-12-03 11:39:14.495729 pestcheck:Line 240937 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.495827 pestcheck:cited more than once.
# 2017-12-03 11:39:14.495938 pestcheck:Line 240938 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.495996 pestcheck:cited more than once.
# 2017-12-03 11:39:14.496098 pestcheck:Line 240939 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.496185 pestcheck:cited more than once.
# 2017-12-03 11:39:14.496270 pestcheck:Line 240940 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.496372 pestcheck:cited more than once.
# 2017-12-03 11:39:14.496428 pestcheck:Line 240941 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.496534 pestcheck:cited more than once.
# 2017-12-03 11:39:14.496585 pestcheck:Line 240942 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.496687 pestcheck:cited more than once.
# 2017-12-03 11:39:14.496743 pestcheck:Line 240943 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.496823 pestcheck:cited more than once.
# 2017-12-03 11:39:14.496907 pestcheck:Line 240944 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.496987 pestcheck:cited more than once.
# 2017-12-03 11:39:14.497089 pestcheck:Line 240945 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.497143 pestcheck:cited more than once.
# 2017-12-03 11:39:14.497221 pestcheck:Line 240946 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.497322 pestcheck:cited more than once.
# 2017-12-03 11:39:14.497359 pestcheck:Line 240947 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.497457 pestcheck:cited more than once.
# 2017-12-03 11:39:14.497558 pestcheck:Line 240948 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.497612 pestcheck:cited more than once.
# 2017-12-03 11:39:14.497715 pestcheck:Line 240949 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.497766 pestcheck:cited more than once.
# 2017-12-03 11:39:14.497850 pestcheck:Line 240950 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.497951 pestcheck:cited more than once.
# 2017-12-03 11:39:14.498006 pestcheck:Line 240951 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.498105 pestcheck:cited more than once.
# 2017-12-03 11:39:14.498159 pestcheck:Line 240952 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.498260 pestcheck:cited more than once.
# 2017-12-03 11:39:14.498315 pestcheck:Line 240953 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.498393 pestcheck:cited more than once.
# 2017-12-03 11:39:14.498494 pestcheck:Line 240954 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.498545 pestcheck:cited more than once.
# 2017-12-03 11:39:14.498647 pestcheck:Line 240955 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.498724 pestcheck:cited more than once.
# 2017-12-03 11:39:14.498778 pestcheck:Line 240956 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.498879 pestcheck:cited more than once.
# 2017-12-03 11:39:14.498930 pestcheck:Line 240957 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.499031 pestcheck:cited more than once.
# 2017-12-03 11:39:14.499086 pestcheck:Line 240958 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.499164 pestcheck:cited more than once.
# 2017-12-03 11:39:14.499266 pestcheck:Line 240959 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.499317 pestcheck:cited more than once.
# 2017-12-03 11:39:14.499420 pestcheck:Line 240960 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.499476 pestcheck:cited more than once.
# 2017-12-03 11:39:14.499555 pestcheck:Line 240961 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.499671 pestcheck:cited more than once.
# 2017-12-03 11:39:14.499780 pestcheck:Line 240962 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.499915 pestcheck:cited more than once.
# 2017-12-03 11:39:14.499995 pestcheck:Line 240963 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.500099 pestcheck:cited more than once.
# 2017-12-03 11:39:14.500233 pestcheck:Line 240964 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.500275 pestcheck:cited more than once.
# 2017-12-03 11:39:14.500381 pestcheck:Line 240965 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.500463 pestcheck:cited more than once.
# 2017-12-03 11:39:14.500546 pestcheck:Line 240966 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.500651 pestcheck:cited more than once.
# 2017-12-03 11:39:14.500728 pestcheck:Line 240967 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.500830 pestcheck:cited more than once.
# 2017-12-03 11:39:14.500912 pestcheck:Line 240968 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.500988 pestcheck:cited more than once.
# 2017-12-03 11:39:14.501096 pestcheck:Line 240969 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.501192 pestcheck:cited more than once.
# 2017-12-03 11:39:14.501295 pestcheck:Line 240970 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.501477 pestcheck:cited more than once.
# 2017-12-03 11:39:14.501584 pestcheck:Line 240971 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.501660 pestcheck:cited more than once.
# 2017-12-03 11:39:14.501731 pestcheck:Line 240972 of file freyberg_pest.pst: model input file arr_mlt/rech0.dat_cn
# 2017-12-03 11:39:14.501814 pestcheck:cited more than once.
# 2017-12-03 11:39:14.502011 finished: running pestchek on freyberg_pest.pst took: 0:00:02.131281
# 2017-12-03 11:39:14.502109 starting: building prior covariance matrix
# 2017-12-03 11:39:14.586076 finished: building prior covariance matrix took: 0:00:00.083967
# 2017-12-03 11:39:14.586340 starting: saving intermediate _setup_<> dfs into schur_test
# /Users/mnfienen/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/mnfienen/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 2017-12-03 11:39:15.615876 finished: saving intermediate _setup_<> dfs into schur_test took: 0:00:01.029536
# 2017-12-03 11:39:15.616054 all done

# %% [markdown]
# # Cool - let's take a quick look at the PST control file this made

# %%
inpst = mfp.pst

# %%
inpst.parameter_data
# Out:
#                   parnme partrans parchglim  parval1  parlbnd  parubnd  \
# hk0_zn1.0      hk0_zn1.0      log    factor      1.0     0.10    10.00
# hk0_zn2.0      hk0_zn2.0      log    factor      1.0     0.10    10.00
# hk0_zn3.0      hk0_zn3.0      log    factor      1.0     0.10    10.00
# hk0_zn4.0      hk0_zn4.0      log    factor      1.0     0.10    10.00
# hk0_zn5.0      hk0_zn5.0      log    factor      1.0     0.10    10.00
# hk0_zn6.0      hk0_zn6.0      log    factor      1.0     0.10    10.00
# sy0_cn            sy0_cn      log    factor      1.0     0.25     1.75
# rech0_cn        rech0_cn      log    factor      1.0     0.75     1.25
# welflux_000  welflux_000      log    factor      1.0     0.10    10.00
#
#                pargp  scale  offset  dercom
# hk0_zn1.0     _znhk0    1.0     0.0       1
# hk0_zn2.0     _znhk0    1.0     0.0       1
# hk0_zn3.0     _znhk0    1.0     0.0       1
# hk0_zn4.0     _znhk0    1.0     0.0       1
# hk0_zn5.0     _znhk0    1.0     0.0       1
# hk0_zn6.0     _znhk0    1.0     0.0       1
# sy0_cn           _cn    1.0     0.0       1
# rech0_cn         _cn    1.0     0.0       1
# welflux_000  welflux    1.0     0.0       1

# %% [markdown]
# # Looks like we have multipliers on our zones. Let's set `noptmax` to -1 to calculate a Jacobian matrix and then see what `pyemu` functionality we can light up

# %% [markdown]
# ## First, though, we can report all the control data to see `noptmax` and everything else

# %%
inpst.control_data.formatted_values
# Out:
# name
# rstfle                        restart
# pestmode                   estimation
# npar                                9
# nobs                            10598
# npargp                              3
# nprior                              0
# nobsgp                             29
# maxcompdim                          0
# ntplfle                           370
# ninsfle                             3
# precis                         single
# dpoint                          point
# numcom                              1
# jacfile                             0
# messfile                            0
# obsreref                   noobsreref
# rlambda1                 2.000000E+01
# rlamfac                 -3.000000E+00
# phiratsuf                3.000000E-01
# phiredlam                1.000000E-02
# numlam                             -7
# jacupdate                         999
# lamforgive                 lamforgive
# derforgive               noderforgive
# relparmax                1.000000E+01
# facparmax                1.000000E+01
# facorig                  1.000000E-03
# iboundstick                         0
# upvecbend                           0
# phiredswh                1.000000E-01
# noptswitch                          1
# splitswh                 1.100000E+00
# doaui                           noaui
# dosenreuse                 nosenreuse
# boundscale               noboundscale
# noptmax                             0
# phiredstp                1.000000E-02
# nphistp                             3
# nphinored                           3
# relparstp                1.000000E-02
# nrelpar                             3
# phistopthresh            0.000000E+00
# lastrun                             1
# phiabandon              -1.000000E+00
# icov                                0
# icor                                0
# ieig                                0
# ires                                0
# jcosave                       jcosave
# verboserec                 verboserec
# jcosaveitn                 jcosaveitn
# reisaveitn                 reisaveitn
# parsaveitn                 parsaveitn
# parsaverun               noparsaverun
# dtype: object

# %%
inpst.control_data.noptmax=-1
inpst.write(os.path.join('schur_test','freyberg_pest.pst'))

# %% [markdown]
# ## Set a flag for whether to run in parallel or not

# %%
parallel = True

# %% [raw]
# ## If we just want to run in serial, we could run at the command line or we can use the following `pyemu` helper function to run `pestpp` for us. The cool thing is, this is operating system agnostic -- it will work regardless of platform.

# %%
if parallel==False:
    pyemu.helpers.run('pestpp freyberg_pest.pst', cwd='schur_test')

# %% [markdown]
# # We can also run in parallel if we want, using the `start_slaves` helper. Set the number of workers you want (all we be launched locally on your machine) and reset parallel to `True`

# %%
parallel = True
if parallel == True:
    num_workers = 12
    os.chdir('schur_test')
    pyemu.helpers.start_slaves('.','pestpp','freyberg_pest.pst',num_slaves=num_workers,master_dir='.')
    os.chdir('..')
# Out:
# master:pestpp freyberg_pest.pst /h :4004 in .
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_0
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_1
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_2
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_3
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_4
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_5
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_6
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_7
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_8
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_9
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_10
# slave:pestpp freyberg_pest.pst /h localhost:4004 in ../slave_11

# %% [markdown]
# # Now, once we have a Jacobian matrix, we can create a posterior Schur complement object. If we don't pass an explicit covariance matrix, the object will use parameter bounds for the prior variance (diagonal matrix) for parameters (also note that if no `.pst` file was passed, `pyemu` will look for one with the same root name in the same location as the `.jco` file that was passed.

# %%
sc = pyemu.Schur(os.path.join('schur_test','freyberg_pest.jcb'))

# %%
sc.jco.x
# Out:
# array([[  1.12992135e-01,  -4.01687040e+01,  -1.39714775e+02, ...,
#           0.00000000e+00,  -2.15798029e+03,   0.00000000e+00],
#        [ -1.12992135e-01,  -3.97167355e+01,   6.11287451e+01, ...,
#           0.00000000e+00,  -1.21924163e+04,   0.00000000e+00],
#        [  0.00000000e+00,  -7.98820188e+01,  -7.85398510e+01, ...,
#           0.00000000e+00,   1.74574118e+02,   0.00000000e+00],
#        ...,
#        [  3.61574832e+02,   4.31720350e+04,   7.69865133e+04, ...,
#           1.62708674e+04,  -8.62370438e+05,   1.07425329e+06],
#        [  1.15703946e+02,   9.25631570e+02,   2.89259866e+03, ...,
#          -3.87608220e+03,  -4.10749009e+03,  -3.87608220e+03],
#        [  0.00000000e+00,  -1.73555919e+02,  -9.86376142e+03, ...,
#          -2.19837498e+04,  -3.55789635e+03,  -3.14998209e+06]])

# %%
inpst.observation_data.obgnme.unique()
# Out:
# array(['flx_constan', 'flx_drains', 'flx_in-out', 'flx_percent',
#        'flx_recharg', 'flx_storage', 'flx_total', 'flx_wells',
#        'i001cr03c16', 'i001cr03c10', 'i001cr04c9', 'i001cr10c2',
#        'i001cr14c11', 'i001cr16c17', 'i001cr22c11', 'i001cr23c16',
#        'i001cr25c5', 'i001cr27c7', 'i001cr30c16', 'i001cr34c8',
#        'i001cr35c11', 'vol_constan', 'vol_drains', 'vol_in-out',
#        'vol_percent', 'vol_recharg', 'vol_storage', 'vol_total',
#        'vol_wells'], dtype=object)
